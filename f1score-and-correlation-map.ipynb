# %%
import pandas as pd

# %%
dt = pd.read_csv('random_search_results.csv')

# %%
dt.sort_values(by='f1_score')
# Out:
#      gran  kernel_size  threshold  selectivity  shift  f1_score
# 44    7.0          4.0   0.980411     2.563288   29.0  0.013500
# 359   7.0          6.0   0.942055     3.633014   29.0  0.019487
# 29    8.0          5.0   0.949726     3.539315   29.0  0.019559
# 67   15.0          1.0   0.990000     0.923562   29.0  0.021605
# 61    9.0          1.0   0.953562     2.149452  -25.0  0.022283
# ..    ...          ...        ...          ...    ...       ...
# 548  31.0          4.0   0.125068     1.189041   13.0  0.577021
# 609  21.0          7.0   0.337945     0.993836   13.0  0.579908
# 42   19.0          7.0   0.034932     2.040137   14.0  0.579994
# 538  12.0          1.0   0.566164     0.173973    5.0  0.587870
# 697  21.0          3.0   0.418493     0.470685   11.0  0.608009
#
# [800 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd



df=dt
# plot the histogram of 'gran' column
# plt.hist(df["gran"], bins=20)
# plt.xlabel("gran")
# plt.ylabel("count")
# plt.title("Distribution of Gran")
# plt.show()

import numpy as np
# plot the correlation heatmap of all columns
plt.figure(figsize=(5.5,5.5))
sns.heatmap(np.round(df.corr(),2), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.savefig('corr.pdf')

# plot the scatter plot of 'quantile' against 'selectivity'
# plt.scatter(df["shift"], df["selectivity"])
# plt.xlabel("Quantile")
# plt.ylabel("Selectivity")
# plt.title("Quantile vs. Selectivity")
# plt.show()

# plot the bar plot of 'metric' against 'f1_score'
# sns.barplot(x="metric", y="f1_score", data=df)
# plt.xlabel("Metric")
# plt.ylabel("F1 Score")
# plt.title("Metric vs. F1 Score")
# plt.show()

# %%
fig, axs = plt.subplots(ncols=3, figsize=(12, 6))
for i, col in enumerate(['gran', 'kernel_size', 'quantile']):
    axs[i].boxplot(df[col], vert=False)
    axs[i].set_title(col.capitalize())
plt.tight_layout()
plt.show()

# create boxplots for columns 'selectivity', 'metric', and 'f1_score'
fig, axs = plt.subplots(ncols=3, figsize=(12, 6))
for i, col in enumerate(['selectivity', 'metric', 'f1_score']):
    axs[i].boxplot(df[col], vert=False)
    axs[i].set_title(col.capitalize())
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(4.5,3))
sns.boxplot(x="metric", y="f1_score", data=df[df.metric!=7][df.metric!=8])
plt.grid()
plt.xlabel("Metric")
plt.ylabel("F1 Score")

plt.title("F1 Score by Metric")
plt.show()
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_10888\4011849112.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.boxplot(x="metric", y="f1_score", data=df[df.metric!=7][df.metric!=8])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# create the dictionary of distance metrics
metric_dict = {
    0: "Bray-Curtis",
    1: "Canberra",
    2: "Chebyshev",
    3: "Manhattan",
    4: "Correlation",
    5: "Cosine",
    6: "Euclidean"
}

# create the plot
plt.figure(figsize=(3.5,3))
sns.boxplot(x="metric", y="f1_score", data=df[df.metric!=7][df.metric!=8])
plt.grid()
plt.xlabel("Metric")
plt.ylabel("F1 Score")
plt.title("F1 Score by Metric")

# set the x tick labels and rotate them
plt.xticks(range(len(metric_dict)), metric_dict.values(), rotation=90)

plt.show()
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_10888\3397681098.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.boxplot(x="metric", y="f1_score", data=df[df.metric!=7][df.metric!=8])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# create the dictionary of distance metrics
metric_dict = {
    0: "Bray-Curtis",
    1: "Canberra",
    2: "Chebyshev",
    3: "Manhattan",
    4: "Correlation",
    5: "Cosine",
    6: "Euclidean"
}

# create the plot
plt.figure(figsize=(3.5,3.5))
sns.boxplot(x="metric", y="f1_score", data=df[df.metric!=7][df.metric!=8])
plt.grid()
plt.xlabel("Metric",fontsize=12)
plt.ylabel("F1 Score",fontsize=12)
# plt.title("F1 Score by Metric")

# set the x tick labels and rotate them
plt.xticks(range(len(metric_dict)), metric_dict.values(), rotation=90)
plt.tight_layout()
# save the plot as a PDF file
plt.savefig("f1_score_by_metric.pdf", format="pdf")

plt.show()
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_10888\4197697557.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.boxplot(x="metric", y="f1_score", data=df[df.metric!=7][df.metric!=8])
